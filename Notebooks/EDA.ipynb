# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# Before we do anything with the data we will first explore it, looking at things like missing data, correlation between missing data (to see if they are random or not), distrubution of numerical values, and so on.

# %%
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

DATA_DIR = "../Data/"

train_dataframe = pd.read_csv(DATA_DIR + "train.csv")
test_dataframe = pd.read_csv(DATA_DIR  + "test.csv")

# %% [markdown]
# ## A first check up

# %%
train_dataframe.head()
# Out:
#    id  person_age  person_income person_home_ownership  person_emp_length  \
# 0   0          37          35000                  RENT                0.0
# 1   1          22          56000                   OWN                6.0
# 2   2          29          28800                   OWN                8.0
# 3   3          30          70000                  RENT               14.0
# 4   4          22          60000                  RENT                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0   EDUCATION          B       6000          11.49                 0.17
# 1     MEDICAL          C       4000          13.35                 0.07
# 2    PERSONAL          A       6000           8.90                 0.21
# 3     VENTURE          B      12000          11.11                 0.17
# 4     MEDICAL          A       6000           6.92                 0.10
#
#   cb_person_default_on_file  cb_person_cred_hist_length  loan_status
# ...

# %%
train_dataframe.tail()
# Out:
#           id  person_age  person_income person_home_ownership  \
# 58640  58640          34         120000              MORTGAGE
# 58641  58641          28          28800                  RENT
# 58642  58642          23          44000                  RENT
# 58643  58643          22          30000                  RENT
# 58644  58644          31          75000              MORTGAGE
#
#        person_emp_length loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 58640                5.0   EDUCATION          D      25000          15.95
# 58641                0.0     MEDICAL          C      10000          12.73
# 58642                7.0   EDUCATION          D       6800          16.00
# 58643                2.0   EDUCATION          A       5000           8.90
# 58644                2.0     VENTURE          B      15000          11.11
#
#        loan_percent_income cb_person_default_on_file  \
# 58640                 0.21                         Y
# ...

# %%
train_dataframe.describe().T
# Out:
#                               count          mean           std      min  \
# id                          58645.0  29322.000000  16929.497605     0.00
# person_age                  58645.0     27.550857      6.033216    20.00
# person_income               58645.0  64046.172871  37931.106978  4200.00
# person_emp_length           58645.0      4.701015      3.959784     0.00
# loan_amnt                   58645.0   9217.556518   5563.807384   500.00
# loan_int_rate               58645.0     10.677874      3.034697     5.42
# loan_percent_income         58645.0      0.159238      0.091692     0.00
# cb_person_cred_hist_length  58645.0      5.813556      4.029196     2.00
# loan_status                 58645.0      0.142382      0.349445     0.00
#
#                                  25%       50%       75%         max
# id                          14661.00  29322.00  43983.00    58644.00
# person_age                     23.00     26.00     30.00      123.00
# ...

# %%
train_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          58645 non-null  int64
#  1   person_age                  58645 non-null  int64
#  2   person_income               58645 non-null  int64
#  3   person_home_ownership       58645 non-null  object
#  4   person_emp_length           58645 non-null  float64
#  5   loan_intent                 58645 non-null  object
#  6   loan_grade                  58645 non-null  object
#  7   loan_amnt                   58645 non-null  int64
#  8   loan_int_rate               58645 non-null  float64
#  9   loan_percent_income         58645 non-null  float64
#  10  cb_person_default_on_file   58645 non-null  object
#  11  cb_person_cred_hist_length  58645 non-null  int64
#  12  loan_status                 58645 non-null  int64
# ...

# %% [markdown]
# From the above we see that we have 9 numerical features (including id and loan status) and 3 categorical features. From the head we also see a bit about what sort of features we got, like the purpose of the loan, their income and their home ownership status.
#
# We will now check to see if there are any null values in the training or test data.

# %%
train_dataframe.isnull().sum()
# Out:
# id                            0
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# loan_status                   0
# dtype: int64

# %%
test_dataframe.isnull().sum()
# Out:
# id                            0
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %% [markdown]
# We see that there are no null values in either the testing or training data set to worry about.

# %%
train_dataframe.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Visulising effect of numerical features.

# %%
numeric_features = [feature for feature in train_dataframe.columns if train_dataframe[feature].dtype != "O" and feature != "id"]


for feature in numeric_features:
    if feature != "loan_status":
        plt.figure(figsize=(6,4))
        sn.scatterplot(x = train_dataframe[feature], y = train_dataframe["loan_status"])

# %% [markdown]
# The first thing we note from this is that no one feature has a impact on loan status except personal income past some amount around 60k.

# %% [markdown]
# ## Visulising Numerical features data distribution

# %% [markdown]
# We will now look at the distrubtion of our features by plotting histograms.

# %%
for feature in numeric_features:
    plt.figure(figsize=(6,4))
    sn.histplot(x = train_dataframe[feature], kde=True)
    plt.title(f"distribution of {feature}")
    plt.show()

# %% [markdown]
# There are a few important things to note here
# * Loan status - many more loans are rejected then approved
# * Loan amount - multi peaked distribution in 5k increments
# * credit history lenght - looks like 3 uniform distributions summed together
# * age and income - very negatively skewed

# %% [markdown]
# ## Vieing effect and distribution of categorical features

# %%
cat_features = [feature for feature in train_dataframe.columns if train_dataframe[feature].dtype == "O"]

for features in cat_features:
    plt.figure(figsize = (6,4))
    sn.countplot(train_dataframe, x = features, hue = "loan_status")

# %% [markdown]
# From this we see that people who rent generally have a higher amount of loans getting accepted, loan intent generally has little difference between amounts accepted and D grade loans seem to have a higher acceptance rate.

# %% [markdown]
# ## Correlation of numeric features

# %%
corr_matrix = train_dataframe[numeric_features].corr()
# Correlation matrix
plt.figure(figsize=(12, 8))
# Plotheatmap
sn.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix - Train Dataset")
plt.show()

# %% [markdown]
# We see that loan amount loan interest rate nad loan $ income are slighty positively correlated with loan status and that personal income is slightly negative correlated. We will view all features once we have done feature engineering in the next notebook.
